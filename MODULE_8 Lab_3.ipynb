# %% [markdown]
# <a href="https://colab.research.google.com/github/Nareshchinna07/FMML_COURSE_ASSIGNMENTS/blob/main/MODULE_8%20Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-06 15:24:21--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   157MB/s    in 0.4s
#
# 2023-05-06 15:24:27 (157 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 40455   1108.6296v2  Tensor decomposition is a powerful computation...    cs
# 12980   0912.5410v1  Networks are ubiquitous in science and have be...  stat
# 25118  1504.07947v5  Convolutional Neural Networks (CNN) are state-...    cs
# 4987   1707.04873v2  Techniques for automatically designing deep ne...    cs
# 32325   1408.6515v3  This paper describes the solution of Bazinga T...    cs
# ...             ...                                                ...   ...
# 13285   0706.1051v1  Neural network models of real-world systems, s...    cs
# 31524  1803.05982v2  With an aim to increase the capture range and ...    cs
# 15994  1608.00892v3  Deep learning has significantly advanced state...    cs
# 23564   1306.2599v1  In this paper, we have proposed a system based...    cs
# 22081   1410.6959v2  $L_1$ regularized logistic regression has now ...  stat
#
#                                                    title  year  \
# 40455  Infinite Tucker Decomposition: Nonparametric B...  2011
# 12980             A survey of statistical network models  2009
# 25118  Patch-based Convolutional Neural Network for W...  2015
# 4987   Efficient Architecture Search by Network Trans...  2017
# 32325  Large Scale Purchase Prediction with Historica...  2014
# ...                                                  ...   ...
# 13285  Improved Neural Modeling of Real-World Systems...  2007
# 31524     Real-time Deep Registration With Geodesic Loss  2018
# 15994  Knowledge Distillation for Small-footprint Hig...  2016
# 23564  Hand Gesture Recognition Based on Karhunen-Loe...  2013
# 22081  An Aggregation Method for Sparse Logistic Regr...  2014
#
#                                                 keywords
# 40455  [decomposition, computational, decomposition, ...
# 12980  [ubiquitous, discussion, statistical, graphica...
# 25118  [convolutional, classification, recognize, aut...
# 4987   [techniques, automatically, designing, archite...
# 32325  [describes, recommendation, platforms, competi...
# ...                                                  ...
# 13285  [industrial, processes, incomplete, predictive...
# 31524  [accelerate, performance, registration, arbitr...
# 15994  [significantly, recognition, conventional, the...
# 23564  [transform, recognize, different, filtering, d...
# 22081  [regularized, regression, workhorse, bioinform...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 40455    [decomposition, computational, decomposition, ...
# 12980    [ubiquitous, discussion, statistical, graphica...
# 25118    [convolutional, classification, recognize, aut...
# 4987     [techniques, automatically, designing, archite...
# 32325    [describes, recommendation, platforms, competi...
#                                ...
# 29610    [representation, supervised, representation, c...
# 2224     [theoretical, justification, classification, p...
# 2865     [polynomial, algorithm, performing, polynomial...
# 6189     [identification, exploration, independently, d...
# 14643    [acquisition, morphological, syntactic, ontolo...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8766 words.
# Out of those 4521 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="59fe491a-b605-4d16-bae6-208903060ad2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59fe491a-b605-4d16-bae6-208903060ad2")) {                    Plotly.newPlot(                        "59fe491a-b605-4d16-bae6-208903060ad2",                        [{"x":["complexities","probabilistic","classical","efficient","nonlinear","continuous","technique","observations","interactions","framework","inference","efficiently","approaches","factorization","processes","prediction","experimental","nonparametric","candecompparafac","implementation","demonstrate","covariance","computational","magnitude","decomposition","significantly","functions","insufficient","chemometrics","variational","emergence","challenges","parameters","representation","communities","historical","development","empirical","graphical","introduce","community","probability","specialized","burgeoning","statistical","prominent","substantial","psychology","interpretation","networking","estimation","description","statistics","subsequent","descriptions","literature","emphasize","generated","attention","discussion","professional","interconnections","ubiquitous","sociology","impossible","differentiation","agreement","convolutional","pathologists","experimentally","comparable","aggregate","knowledge","currently","intelligently","challenge","computationally","expectation","resolution","classifier","maximization","carcinoma","furthermore","relationships","classification","recognize","therefore","utilizing","predictions","automatically","outperform","formulate","situation","discriminative","resources","difficult","inefficient","promising","branching","designing","restricted","validated","architecture","exceeding","controller","approaching","noticeable","connections","exploration","previously","architectures","reinforcement","transformation","exploring","benchmark","transformations","competitive","preserving","limitation","techniques","purchases","considers","mapreduce","precision","individual","regression","platforms","describes","aggregated","evaluation","recommendation","competition","distributed","competitors","regularized","dimensional","extensive","penalized","convergence","performing","theoretical","correlation","functional","comparison","selection","contemporary","likelihood","properties","optimization","demonstrably","rigorously","comparisons","proposing","tremendous","undertake","minimization","coordinate","leveraged","challenging","workflows","importance","application","vectorization","algorithms","scribbles","qualitatively","paramount","procedures","transforms","modification","vectorizing","simplified","extensively","vectorized","different","extraction","contributions","algorithm","resulting","important","structure","iterative","characterization","direction","alternate","locations","procedure","multiplier","fundamental","optimizing","particularly","collections","estimations","constraint","corresponding","available","symmetric","involving","potential","production"],"y":[9,128,111,412,65,103,270,70,77,521,215,157,426,29,82,247,382,16,1,144,540,21,300,58,55,291,232,10,1,45,14,113,225,378,27,25,108,147,59,326,79,160,16,0,143,12,50,14,61,5,189,86,58,20,54,120,8,184,171,23,5,1,16,1,16,8,16,409,4,49,93,21,320,61,5,162,86,24,119,146,28,3,146,63,521,47,132,39,90,187,99,48,32,103,85,140,13,110,6,51,49,30,253,2,19,7,5,43,68,87,134,103,47,42,228,39,117,44,23,373,2,32,6,90,121,115,39,100,11,265,37,34,103,8,31,184,184,4,124,86,154,75,40,146,131,17,56,204,311,0,5,29,29,10,3,56,26,10,243,4,73,255,2,583,2,13,4,36,17,25,1,17,31,4,725,127,42,832,146,343,295,73,25,67,9,41,98,6,81,50,82,26,7,98,141,307,16,55,148,23],"type":"bar"},{"x":["complexities","probabilistic","classical","efficient","nonlinear"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4521,), (4521, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Update</span> <span style=''>Strength</span> <span style=''>in</span> <span style=''>EDAs</span> <span style=''>and</span> <span style=''>ACO</span> <span style=''>How</span> <span style=''>to</span> <span style=''>Avoid</span> <span style=''>Genetic</span> <span style=''>Drift</span> <br/><br/><span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>rigorous</span> <span style=''>runtime</span> <span style=''>analysis</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>concerning</span> <span style=''>the</span> <span style=''>update</span> <span style=''>strength</span> <span style=''>a</span> <span style=''>vital</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>building</span> <span style=''>GAs</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>step</span> <span style=''>size</span> <span style=''>1K</span> <span style=''>in</span> <span style=''>the</span> <span style=''>compact</span> <span style=''>Genetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>(cGA)</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>evaporation</span> <span style=''>factor</span> <span style=''>rho</span> <span style=''>in</span> <span style=''>ACO</span> <span style=''>While</span> <span style=''>a</span> <span style=''>large</span> <span style=''>update</span> <span style=''>strength</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>desirable</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploitation</span> <span style=''>there</span> <span style=''>is</span> <span style=''>a</span> <span style=''>general</span> <span style=''>trade</span> <span style=''>off</span> <span style=''>too</span> <span style=''>strong</span> <span style=''>updates</span> <span style=''>can</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>genetic</span> <span style=''>drift</span> <span style=''>and</span> <span style=''>poor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>this</span> <span style=''>trade</span> <span style=''>off</span> <span style=''>for</span> <span style=''>the</span> <span style=''>cGA</span> <span style=''>and</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>MMAS</span> <span style=''>ACO</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>on</span> <span style=''>the</span> <span style=''>OneMax</span> <span style=''>function</span> <span style=''>More</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precisely</span> <span style=''>we</span> <span style=''>obtain</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>runtime</span> <span style=''>of</span> <span style=''>Omega(Ksqrtn</span> <span style=''>n</span> <span style=''>log</span> <span style=''>n)</span> <span style=''>and</span> <span style=''>Omega(sqrtnrho</span> <span style=''>n</span> <span style=''>log</span> <span style=''>n)</span> <span style='background-color:rgba(0, 255, 0, 0.41463414634146334);'>respectively</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>the</span> <span style=''>update</span> <span style=''>strength</span> <span style=''>should</span> <span style=''>be</span> <span style=''>limited</span> <span style=''>to</span> <span style=''>1K</span> <span style=''>rho</span> <span style=''>O(1(sqrtn</span> <span style=''>lo ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>Conical</span> <span style=''>Hull</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>Near</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separable</span> <span style=''>Non</span> <span style=''>negative</span> <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorization</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>(Donoho</span> <span style=''>Stodden</span> <span style=''>2003</span> <span style=''>Arora</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2012)</span> <span style=''>turns</span> <span style=''>non</span> <span style=''>negative</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>(NMF)</span> <span style=''>into</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractable</span> <span style=''>problem</span> <span style=''>Recently</span> <span style=''>a</span> <span style=''>new</span> <span style=''>class</span> <span style=''>of</span> <span style=''>provably</span> <span style=''>correct</span> <span style=''>NMF</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>emerged</span> <span style=''>under</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reformulate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separable</span> <span style=''>NMF</span> <span style=''>problem</span> <span style=''>as</span> <span style=''>that</span> <span style=''>of</span> <span style=''>finding</span> <span style=''>the</span> <span style=''>extreme</span> <span style=''>rays</span> <span style=''>of</span> <span style=''>the</span> <span style=''>conical</span> <span style=''>hull</span> <span style=''>of</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>set</span> <span style=''>of</span> <span style=''>vectors</span> <span style=''>From</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geometric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspective</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separable</span> <span style=''>NMF</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>are</span> <span style=''>highly</span> <span style=''>scalable</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirically</span> <span style=''>noise</span> <span style=''>robust</span> <span style=''>and</span> <span style=''>have</span> <span style=''>several</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>favorable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>in</span> <span style=''>relation</span> <span style=''>to</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>A</span> <span style=''>parallel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrates</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scalability</span> <span style=''>on</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Multi</span> <span style=''>Step</span> <span style='background-color:rgba(255, 0, 0, 0.3589743589743589);'>Stochastic</span> <span style=''>ADMM</span> <span style=''>in</span> <span style=''>High</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dimensions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Applications</span> <span style=''>to</span> <span style=''>Sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>and</span> <span style=''>Noisy</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Decomposition</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>ADMM</span> <span style=''>method</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.32978723404255306);'>guarantees</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.36221837088388215);'>dimensional</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>explicit</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>the</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>the</span> <span style=''>noisy</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>problem</span> <span style=''>For</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establish</span> <span style=''>that</span> <span style=''>the</span> <span style=''>modified</span> <span style=''>ADMM</span> <span style=''>method</span> <span style=''>has</span> <span style=''>an</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>of</span> <span style=''>mathcalO(slog</span> <span style=''>dT)</span> <span style=''>where</span> <span style=''>s</span> <span style=''>is</span> <span style=''>the</span> <span style=''>sparsity</span> <span style=''>level</span> <span style=''>d</span> <span style=''>is</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimension</span> <span style=''>and</span> <span style=''>T</span> <span style=''>is</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>steps</span> <span style=''>This</span> <span style=''>matches</span> <span style=''>with</span> <span style=''>the</span> <span style=''>minimax</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>For</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>into</span> <span style=''>sparse</span> <span style=''>and</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.32978723404255306);'>guarantees</span> <span style=''>for</span> <span style=''>any</span> <span style=''>online</span> <span style=''>method</span> <span style=''>and</span> <span style=''>prove</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>of</span> <span style=''>tildemathc ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Empirical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Comparison</span> <span style=''>of</span> <span style=''>V</span> <span style=''>fold</span> <span style=''>Penalisation</span> <span style=''>and</span> <span style=''>Cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Validation</span> <span style=''>for</span> <span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distribution</span> <span style=''>Free</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <br/><br/><span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>is</span> <span style=''>a</span> <span style=''>crucial</span> <span style=''>issue</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>penalisation</span> <span style=''>methods</span> <span style=''>(with</span> <span style=''>possibly</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>penalties)</span> <span style=''>have</span> <span style=''>recently</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>for</span> <span style=''>this</span> <span style=''>purpose</span> <span style=''>However</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style=''>not</span> <span style=''>well</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>documented</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>It</span> <span style=''>is</span> <span style=''>the</span> <span style=''>goal</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>to</span> <span style=''>which</span> <span style=''>extent</span> <span style=''>such</span> <span style=''>recent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successfully</span> <span style=''>used</span> <span style=''>for</span> <span style=''>the</span> <span style=''>tuning</span> <span style=''>of</span> <span style=''>both</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularisation</span> <span style=''>and</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>in</span> <span style=''>support</span> <span style=''>vector</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>(SVR)</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>measure</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>trees</span> <span style=''>(CART)</span> <span style=''>This</span> <span style=''>task</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditionally</span> <span style=''>solved</span> <span style=''>via</span> <span style=''>V</span> <span style=''>fold ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10624551328068917)
# 	architecture (0.09081119885139986)
# 	segmentation (0.07250538406317301)
# 	experimental (0.13711414213926776)
# 	representation (0.135678391959799)
# 	information (0.24910265613783203)
# 	different (0.26022972002871503)
# 	detection (0.1299353912419239)
# 	recognition (0.13819095477386933)
# 	convolutional (0.14680545585068197)
#
# Some Statistics words are:
# 	stochastic (0.13157894736842105)
# 	algorithm (0.3857994041708044)
# 	variables (0.13406156901688182)
# 	theoretical (0.1564051638530288)
# 	estimation (0.17030784508440913)
# 	statistical (0.15739821251241312)
# 	distribution (0.1871896722939424)
# 	inference (0.2035749751737835)
# 	dimensional (0.1951340615690169)
# 	regression (0.18321747765640517)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f2934d53-c497-4598-9ec9-f0932fd5d61b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2934d53-c497-4598-9ec9-f0932fd5d61b")) {                    Plotly.newPlot(                        "f2934d53-c497-4598-9ec9-f0932fd5d61b",                        [{"x":["complexities","probabilistic","classical","efficient","nonlinear","continuous","technique","observations","interactions","framework","inference","efficiently","approaches","factorization","processes","prediction","experimental","nonparametric","candecompparafac","implementation","demonstrate","covariance","computational","magnitude","decomposition","significantly","functions","insufficient","chemometrics","variational","emergence","challenges","parameters","representation","communities","historical","development","empirical","graphical","introduce","community","probability","specialized","burgeoning","statistical","prominent","substantial","psychology","interpretation","networking","estimation","description","statistics","subsequent","descriptions","literature","emphasize","generated","attention","discussion","professional","interconnections","ubiquitous","sociology","impossible","differentiation","agreement","convolutional","pathologists","experimentally","comparable","aggregate","knowledge","currently","intelligently","challenge","computationally","expectation","resolution","classifier","maximization","carcinoma","furthermore","relationships","classification","recognize","therefore","utilizing","predictions","automatically","outperform","formulate","situation","discriminative","resources","difficult","inefficient","promising","branching","designing","restricted","validated","architecture","exceeding","controller","approaching","noticeable","connections","exploration","previously","architectures","reinforcement","transformation","exploring","benchmark","transformations","competitive","preserving","limitation","techniques","purchases","considers","mapreduce","precision","individual","regression","platforms","describes","aggregated","evaluation","recommendation","competition","distributed","competitors","regularized","dimensional","extensive","penalized","convergence","performing","theoretical","correlation","functional","comparison","selection","contemporary","likelihood","properties","optimization","demonstrably","rigorously","comparisons","proposing","tremendous","undertake","minimization","coordinate","leveraged","challenging","workflows","importance","application","vectorization","algorithms","scribbles","qualitatively","paramount","procedures","transforms","modification","vectorizing","simplified","extensively","vectorized","different","extraction","contributions","algorithm","resulting","important","structure","iterative","characterization","direction","alternate","locations","procedure","multiplier","fundamental","optimizing","particularly","collections","estimations","constraint","corresponding","available","symmetric","involving","potential","production","conventional","programming","uncertainty","combinatorial","implemented","semantics","modelling","dimensions","illustrate","constraints","stochastic","agriculture","scenarios","adversarial","conditional","generative","detection","classifiers","distribution","developed","robustness","adversaries","distances","closeness","normalized","scalability","practical","estimated","computations","estimates","preprocessing","structural","increasing","polynomially","centrality","guarantees","information","radiological","radiation","sequentially","recurrent","informative","experiments","containing","abnormality","performed","abnormalities","partition","superpixel","quantitative","generation","conducted","outperforms","combining","construc ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	burgeoning
# 	demonstrably
# 	hamiltonian
# 	hamiltonians
# 	couplings
# 	triggering
# 	subsample
# 	precisions
# 	concordance
# 	projectorg
# 	transports
# 	subpopulations
# 	heterogenous
# 	homoscedastic
# 	heteroscedastic
# 	underpowered
# 	terabytes
# 	integrative
# 	wirtinger
# 	protecting
# Some words which never appear in Statistics papers:
# 	carcinoma
# 	scribbles
# 	agriculture
# 	superpixel
# 	conversational
# 	assistants
# 	dialogues
# 	ambitious
# 	primitive
# 	irrelevance
# 	disjunctive
# 	comprehension
# 	addressee
# 	collocation
# 	ontological
# 	concatenation
# 	speculate
# 	isomorphic
# 	altogether
# 	ultrasound

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.088230752601835e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.765
